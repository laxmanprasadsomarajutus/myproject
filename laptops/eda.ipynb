# %%
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# import seaborn as sns

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv('./data/processed.csv')

# %%
correlation_matrix = data.drop(columns=["product_id"]).corr()

# Create the heatmap
plt.figure(figsize=(20, 10))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
data.dtypes
# Out:
# product_id                object
# mrp                        int64
# os                         int64
# hard_disk_type             int64
# ram_memory                 int64
# processor_brand            int64
# processor_count            int64
# display_type               int64
# form_factor                int64
# screen_res_w               int64
# screen_res_h               int64
# length                   float64
# width                    float64
# height                   float64
# weight                   float64
# hard_drive_size_value      int64
# hard_drive_size_unit       int64
# battery_type               int64
# is_success                  bool
# dtype: object

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 10))
plt.subplots_adjust(hspace=0.4)

# Define numeric columns
numeric_cols = ['mrp', 'os', 'hard_disk_type', 'ram_memory', 'processor_brand', 'processor_count',
                'display_type', 'form_factor', 'screen_res_w', 'screen_res_h', 'length', 'width',
                'height', 'weight', 'hard_drive_size_value', 'hard_drive_size_unit']

num_plots = len(numeric_cols)
num_rows = 3
num_cols = 3

# Plot histograms for numeric columns
for i, col in enumerate(numeric_cols):
    ax = axes[i // num_cols, i % num_cols]
    ax.hist(data[col], bins=20)
    ax.set_title(col)
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')
    if i == num_plots - 1:
        ax.axis('off')  # Hide the empty subplot if the number of columns is not a perfect square

# Show the histogram plots
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 15
#      13 # Plot histograms for numeric columns
#      14 for i, col in enumerate(numeric_cols):
# ---> 15     ax = axes[i // num_cols, i % num_cols]
#      16     ax.hist(data[col], bins=20)
#      17     ax.set_title(col)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
# Create a box plot for numeric columns
sns.boxplot(data=data[numeric_cols])
plt.title('Box Plots')
plt.xticks(rotation=45)
plt.xlabel('Column')
plt.ylabel('Value')

# Show the box plot
plt.tight_layout()
plt.show()

# %%
# Define categorical columns
categorical_cols = ['os', 'hard_disk_type', 'processor_brand', 'display_type', 'form_factor', 'hard_drive_size_unit']

# Create bar plots for categorical columns
for col in categorical_cols:
    sns.countplot(data=data, x=col)
    plt.title('Bar Plot: ' + col)
    plt.xlabel(col)
    plt.ylabel('Count')

    # Show the bar plot
    plt.tight_layout()
    plt.show()

# %%
# Create a pair plot for numeric columns
sns.pairplot(data[numeric_cols])
plt.suptitle('Pair Plot')

# Show the pair plot
plt.tight_layout()
plt.show()
