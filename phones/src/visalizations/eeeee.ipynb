# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv('../../data/processed-v2.csv')

# %%
# Quick overview of the dataset
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    product_id    mrp  no of 5 star  no of 4 star  no of 3 star  no of 2 star
# 0  B09TWH8YHM  18499         15088          7401          2562           854  \
# 1  B0B4F38D6K  12999         11687          5843          2247           674
# 2  B0B56YRDDT   7799          2499          1122           510           204
# 3  B0BZ466BWW  12999           777           259            90            38
# 4  B0BYN48MQW   8799           514           201           100            40
#
#    no of 1 star  ram  inbuilt_storage  weight  ...  cam_has_AI  cam_has_OIS
# 0          2562  8.0            128.0     215  ...           0            0  \
# 1          2022  6.0            128.0     207  ...           0            0
# 2           714  4.0             64.0     194  ...           0            0
# 3           129  6.0            128.0     190  ...           0            0
# 4           151  4.0             64.0     192  ...           0            0
#
#    cam_has_Zoom  cam_has_HDR  cam_has_Macro  cam_has_Portrait  main_camera_MP
# 0             0            0              0                 0              50  \
# 1             0            0              0                 0              12
# 2             0            0              0                 0              13
# 3             0            0              0                 0              12
# 4             0            0              0                 0              12
#
#    is_success  no_ratings  avg_rating
# 0        True       28467    4.110022
# 1        True       22473    4.090153
# 2        True        5049    3.888889
# 3        True        1293    4.173241
# 4        True        1006    3.881710
#
# [5 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_id               636 non-null    object
#  1   mrp                      636 non-null    int64
#  2   no of 5 star             636 non-null    int64
#  3   no of 4 star             636 non-null    int64
#  4   no of 3 star             636 non-null    int64
#  5   no of 2 star             636 non-null    int64
#  6   no of 1 star             636 non-null    int64
#  7   ram                      636 non-null    float64
#  8   inbuilt_storage          636 non-null    float64
#  9   weight                   636 non-null    int64
#  10  battery_power            636 non-null    int64
#  11  battery_type             636 non-null    int64
#  12  form_factor              636 non-null    int64
#  13  length                   636 non-null    float64
#  14  width                    636 non-null    float64
#  15  height                   636 non-null    float64
#  16  os_name                  636 non-null    int64
#  17  os_version               636 non-null    float64
#  18  phone_warranty (months)  636 non-null    int64
#  19  camera_count             636 non-null    int64
#  20  cam_has_AI               636 non-null    int64
#  21  cam_has_OIS              636 non-null    int64
#  22  cam_has_Zoom             636 non-null    int64
#  23  cam_has_HDR              636 non-null    int64
#  24  cam_has_Macro            636 non-null    int64
#  25  cam_has_Portrait         636 non-null    int64
#  26  main_camera_MP           636 non-null    int64
#  27  is_success               636 non-null    bool
#  28  no_ratings               636 non-null    int64
#  29  avg_rating               628 non-null    float64
# dtypes: bool(1), float64(7), int64(21), object(1)
# memory usage: 144.8+ KB
# None
#                  mrp   no of 5 star  no of 4 star  no of 3 star  no of 2 star
# count     636.000000     636.000000     636.00000    636.000000    636.000000  \
# mean    21808.328616    6011.894654    2785.25000    996.319182    343.328616
# std     17992.044321   19481.296991    9402.25012   3634.452196   1085.614072
# min      2790.000000       0.000000       0.00000      0.000000      0.000000
# 25%      9499.000000      97.750000      38.75000     17.000000      8.000000
# 50%     15990.000000     785.000000     287.00000    111.000000     41.000000
# 75%     27999.000000    2671.000000    1297.25000    516.000000    216.000000
# max    164999.000000  171808.000000   84283.00000  35658.000000   9725.000000
#
#        no of 1 star         ram  inbuilt_storage      weight  battery_power
# count    636.000000  636.000000       636.000000  636.000000     636.000000  \
# mean     895.006289    6.303459       117.448050  213.179245    4739.965409
# std     2559.590229    5.638721        70.785693   75.807273     902.695626
# min        0.000000    0.500000         0.480000   90.000000      10.000000
# 25%       24.500000    4.000000        64.000000  188.000000    4700.000000
# 50%      173.500000    6.000000       128.000000  194.000000    5000.000000
# 75%      692.000000    8.000000       128.000000  205.000000    5000.000000
# max    22691.000000  128.000000       512.000000  728.000000    6000.000000
#
#        ...  camera_count  cam_has_AI  cam_has_OIS  cam_has_Zoom  cam_has_HDR
# count  ...    636.000000  636.000000   636.000000    636.000000   636.000000  \
# mean   ...      2.503145    0.210692     0.209119      0.207547     0.207547
# std    ...      1.196447    0.408121     0.407000      0.405870     0.405870
# min    ...      2.000000    0.000000     0.000000      0.000000     0.000000
# 25%    ...      2.000000    0.000000     0.000000      0.000000     0.000000
# 50%    ...      2.000000    0.000000     0.000000      0.000000     0.000000
# 75%    ...      2.000000    0.000000     0.000000      0.000000     0.000000
# max    ...     11.000000    1.000000     1.000000      1.000000     1.000000
#
#        cam_has_Macro  cam_has_Portrait  main_camera_MP     no_ratings
# count     636.000000        636.000000      636.000000     636.000000  \
# mean        0.205975          0.210692       20.056604   11031.798742
# std         0.404730          0.408121       17.944094   36076.848649
# min         0.000000          0.000000        2.000000       0.000000
# 25%         0.000000          0.000000       12.000000     191.750000
# 50%         0.000000          0.000000       12.000000    1337.000000
# 75%         0.000000          0.000000       12.000000    5401.500000
# max         1.000000          1.000000      108.000000  324165.000000
#
#        avg_rating
# count  628.000000
# mean     3.954119
# std      0.475637
# min      1.000000
# 25%      3.845453
# 50%      4.029921
# 75%      4.220103
# max      5.000000
#
# [8 rows x 28 columns]

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# product_id                 0
# mrp                        0
# no of 5 star               0
# no of 4 star               0
# no of 3 star               0
# no of 2 star               0
# no of 1 star               0
# ram                        0
# inbuilt_storage            0
# weight                     0
# battery_power              0
# battery_type               0
# form_factor                0
# length                     0
# width                      0
# height                     0
# os_name                    0
# os_version                 0
# phone_warranty (months)    0
# camera_count               0
# cam_has_AI                 0
# cam_has_OIS                0
# cam_has_Zoom               0
# cam_has_HDR                0
# cam_has_Macro              0
# cam_has_Portrait           0
# main_camera_MP             0
# is_success                 0
# no_ratings                 0
# avg_rating                 8
# dtype: int64

# %%
# Data distribution visualization for 'is_success' (target column)
sns.countplot(x='is_success', data=df)
plt.title('Target Class Distribution')
plt.show()

# %%
correlation_matrix = df.drop(columns=["product_id"]).corr()

# Create the heatmap
plt.figure(figsize=(20, 10))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Histograms for numerical features
df.hist(figsize=(12, 10))
plt.suptitle('Histograms of Numerical Features', fontsize=12)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Boxplots for numerical features
df.boxplot(figsize=(12, 6))
plt.title('Boxplots of Numerical Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Pairplot for selected features
sns.pairplot(df[['mrp', 'ram', 'inbuilt_storage', 'battery_power', 'is_success']], hue='is_success')
plt.title('Pairplot of Selected Features')
plt.show()

# %%
# Bar plots for categorical features
sns.countplot(x='battery_type', data=df)
plt.title('Battery Type Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='form_factor', data=df)
plt.title('Form Factor Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
# Explore relationships between features and target
sns.boxplot(x='is_success', y='mrp', data=df)
plt.title('Relationship between Target and MRP')
plt.show()

# %%
sns.boxplot(x='is_success', y='ram', data=df)
plt.title('Relationship between Target and RAM')
plt.show()

# %%
sns.violinplot(x='is_success', y='main_camera_MP', data=df)
plt.title('Relationship between Target and Main Camera MP')
plt.show()

# %%
# Additional charts and visualizations
sns.scatterplot(x='battery_power', y='inbuilt_storage', hue='is_success', data=df)
plt.title('Scatterplot: Battery Power vs. Inbuilt Storage')
plt.show()

# %%
sns.barplot(x='os_name', y='is_success', data=df)
plt.title('Mean Success Rate per OS Name')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x='cam_has_AI', y='is_success', data=df)
plt.title('Success Rate based on Camera AI')
plt.show()

# %%
sns.boxplot(x='is_success', y='weight', data=df)
plt.title('Relationship between Target and Weight')
plt.show()

# %%
sns.countplot(x='phone_warranty (months)', hue='is_success', data=df)
plt.title('Success Rate per Phone Warranty Duration')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='is_success', y='os_version', data=df)
plt.title('Relationship between Target and OS Version')
plt.show()

# %%
sns.heatmap(pd.crosstab(df['is_success'], df['ram']), annot=True, cmap='coolwarm')
plt.title('Cross-tabulation: RAM vs. Success')
plt.show()
